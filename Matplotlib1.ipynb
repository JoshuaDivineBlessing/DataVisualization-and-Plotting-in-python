# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,4])

# %%
plt.ylabel('some numbers')
# Out:
# Text(0,0.5,'some numbers')

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numbers')
plt.show()
